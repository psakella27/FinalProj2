# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

#loading data
df = pd.read_pickle('/Users/pranavakella/Documents/GitHub/FinalProj/data/covid_sample-0.0001.pkl')

df
df2 = df[df["location"].notna()]

df_trump = df[df["screen_name"] == "realDonaldTrump"]

df_trump

df3 = df[df["description"].notna()]

df3
# Out:
#                     tweetid               userid      screen_name  \
# 29075   1440152419048955908  1389342585823584263  josephc14074803
# 78531   1406520004389003265            342937716        abuVeliki
# 116174  1469680656062025734  1442745694700326917       pisu_laura
# 126940  1486139877456596999   751469205166358528      Chris_V_C_M
# 54016   1388890525177106440             47327823           Lavy02
# ...                     ...                  ...              ...
# 17720   1520829660048748544  1471743605622509571  Mohamma04947722
# 30863   1534210767179763712  1456423688731988019          MilaK21
# 47554   1453744714730012677             19994423         dfarquha
# 161110  1477836631067566081  1285057167884722178       bIuesundae
# 11663   1496954995488419850           3320990612  JThomasOfficial
#
#                                   date lang      location place_id place_url  \
# 29075   Tue Sep 21 03:14:28 +0000 2021   en           NaN      NaN       NaN
# ...
